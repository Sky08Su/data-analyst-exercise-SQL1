# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Bookings_Data.csv', index_col=0)
df
# Out:
#      Sales Segment Global Region                      Industry
# ID
# 1       Enterprise           NaN  Internet Software & Services  \
# 2       Enterprise           NaN  Internet Software & Services
# 3         Emerging           NaN                           NaN
# 4         Emerging           NaN                           NaN
# 5         Emerging           NaN             Business Services
# ...            ...           ...                           ...
# 3695      Emerging           NaN  Internet Software & Services
# 3696           SMB           NaN  Internet Software & Services
# 3697      Emerging           NaN                     Education
# 3698           SMB           NaN  Internet Software & Services
# 3699    Enterprise           NaN         Professional Services
#
#      Booking Date Date Lead Source      Type Reporting Type Reason
# ID
# 1           2024-06-27     Website  New Deal                   New  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3699 entries, 1 to 3699
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sales Segment           3699 non-null   object
#  1   Global Region           524 non-null    object
#  2   Industry                3331 non-null   object
#  3   Booking Date Date       3699 non-null   object
#  4   Lead Source             1170 non-null   object
#  5   Type                    3699 non-null   object
#  6   Reporting Type Reason   3676 non-null   object
#  7   Stage Name              3699 non-null   object
#  8   Source                  1170 non-null   object
#  9   Number of Employees     3125 non-null   object
#  10  Is Customer (Yes / No)  3699 non-null   object
#  11  Created Date            3699 non-null   object
#  12  Tenure Months           3693 non-null   object
#  13  Total ARR               3699 non-null   object
# dtypes: object(14)
# ...

# %%
df.isnull().sum()
# Out:
# Sales Segment                0
# Global Region             3175
# Industry                   368
# Booking Date Date            0
# Lead Source               2529
# Type                         0
# Reporting Type Reason       23
# Stage Name                   0
# Source                    2529
# Number of Employees        574
# Is Customer (Yes / No)       0
# Created Date                 0
# Tenure Months                6
# Total ARR                    0
# dtype: int64

# %%
sns.countplot(df['Stage Name'])
# Out:
# F:\Application\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Stage Name', ylabel='count'>

# %%
df['Stage Name'].value_counts()
# Out:
# Stage Name
# Closed Won      2944
# Closed Lost      608
# Disqualified     147
# Name: count, dtype: int64

# %%
plt.hist(df['Sales Segment'])
# Out:
# (array([ 313.,    0.,    0., 1908.,    0.,    0., 1303.,    0.,    0.,
#          175.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)
